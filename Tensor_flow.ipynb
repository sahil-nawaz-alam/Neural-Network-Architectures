# %%
import tensorflow as tf
print(tf.version)
# Out:
# <module 'tensorflow._api.v2.version' from 'C:\\Users\\Sahil\\anaconda3\\Lib\\site-packages\\tensorflow\\_api\\v2\\version\\__init__.py'>

# %%
tf.__version__
# Out:
# '2.20.0'

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\Sahil\AppData\Local\Temp\ipykernel_17320\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %%
x=tf.constant(10)
x
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=10>

# %%
y=tf.constant(10.5)
y
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=10.5>

# %%
z=tf.constant("India")
z
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'India'>

# %%
s=tf.constant([1,2,3,4,5,6])
s
# Out:
# <tf.Tensor: shape=(6,), dtype=int32, numpy=array([1, 2, 3, 4, 5, 6], dtype=int32)>

# %%
import numpy as np
a=np.array([[1,2,3],[4,5,6]])
tf.constant(a)
# Out:
# <tf.Tensor: shape=(2, 3), dtype=int64, numpy=
# array([[1, 2, 3],
#        [4, 5, 6]])>

# %%
t2d=tf.constant([[1,2],[3,4]])
t2d
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[1, 2],
#        [3, 4]], dtype=int32)>

# %%
t1d=tf.constant([[1,2,3,4]])
t1d
# Out:
# <tf.Tensor: shape=(1, 4), dtype=int32, numpy=array([[1, 2, 3, 4]], dtype=int32)>

# %%
t2d1=tf.constant([1,2,3,4],shape=(2,2),dtype='int32')
t2d1
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[1, 2],
#        [3, 4]], dtype=int32)>

# %%
t3d1=tf.constant([[1,2],[3,4],[5,6]],shape=(2,3),dtype='float32')
t3d1
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[1., 2., 3.],
#        [4., 5., 6.]], dtype=float32)>

# %%
type(t3d1)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
t3d1.shape
# Out:
# TensorShape([2, 3])

# %%
tf.Variable(1)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=1>

# %%
x = tf.Variable([4, 5, 2, 9])
x.assign([1, 2, 3, 4])
# Out:
# <tf.Variable 'UnreadVariable' shape=(4,) dtype=int32, numpy=array([1, 2, 3, 4], dtype=int32)>

# %%
x = tf.Variable([4, 5, 2, 9])
x.assign_add([4, 5, 1, 8])
# Out:
# <tf.Variable 'UnreadVariable' shape=(4,) dtype=int32, numpy=array([ 8, 10,  3, 17], dtype=int32)>

# %% [markdown]
# # **Tensor flow with modules**

# %%
import tensorflow as tf
print(tf.version)

# %%
a=10
b=20

# %%
a+b
# Out:
# 30

# %%
tf.add(a,b)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=30>

# %%
l1=[1,2,4,45]
l2=[43,5,24,41]
tf.add(l1,l2)
# Out:
# <tf.Tensor: shape=(4,), dtype=int32, numpy=array([44,  7, 28, 86], dtype=int32)>
